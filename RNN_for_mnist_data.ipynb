# %% [markdown]
# <a href="https://colab.research.google.com/github/Nivetha72006/Deep-Learning/blob/main/RNN_for_mnist_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import LSTM,Input,Dense
from tensorflow.keras.models import Model

# %%
mnist=keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train,x_test=x_train/255.0,x_test/255.0

# %%
inputs=Input(shape=(28,28))
rnn_layer=LSTM(128)(inputs)
outputs=Dense(10,activation='softmax')(rnn_layer)
model=Model(inputs=inputs,outputs=outputs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,validation_split=0.1,epochs=10)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 62s 35ms/step - accuracy: 0.8856 - loss: 0.3586 - val_accuracy: 0.9573 - val_loss: 0.1293
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 79s 34ms/step - accuracy: 0.9659 - loss: 0.1120 - val_accuracy: 0.9720 - val_loss: 0.0965
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 58s 34ms/step - accuracy: 0.9758 - loss: 0.0800 - val_accuracy: 0.9743 - val_loss: 0.0830
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 58s 34ms/step - accuracy: 0.9809 - loss: 0.0631 - val_accuracy: 0.9828 - val_loss: 0.0564
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 58s 34ms/step - accuracy: 0.9846 - loss: 0.0495 - val_accuracy: 0.9835 - val_loss: 0.0537
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 58s 35ms/step - accuracy: 0.9866 - loss: 0.0418 - val_accuracy: 0.9862 - val_loss: 0.0508
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 57s 34ms/step - accuracy: 0.9891 - loss: 0.0347 - val_accuracy: 0.9867 - val_loss: 0.0443
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 85s 36ms/step - accuracy: 0.9903 - loss: 0.0318 - val_accuracy: 0.9847 - val_loss: 0.0504
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 79s 34ms/step - accuracy: 0.9908 - loss: 0.0282 - val_accuracy: 0.9875 - val_loss: 0.0489
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 57s 34ms/step - accuracy: 0.9923 - loss: 0.0245 - val_accuracy: 0.9865 - val_loss: 0.0483

# %%
y_pred=model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step

# %%
import numpy as np
y_pred1=np.argmax(y_pred,axis=1)
print(y_pred1[2345])
# Out:
# 9

# %%
import matplotlib.pyplot as plt
t=y_test[3456]
s=y_pred1[3456]
plt.title(f"y_test:{t},y_pred1:{s}")
plt.imshow(x_test[3456],cmap='gray')
